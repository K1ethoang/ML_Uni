# %% [markdown]
# # Linear Regression with Dataset ***Fish species sampling data - legnth and weight***
# - https://www.kaggle.com/datasets/taweilo/fish-species-sampling-weight-and-height-data

# %% [markdown]
# # Connect to GG drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_dataset = "/content/drive/MyDrive/Class/nam-4/ky-1/ML/TH1/dataset"

# %% [markdown]
# # Read data

# %%
import pandas as pd

df_data = pd.read_csv(path_dataset + "/fish_data.csv")
df_data.tail()
# Out:
#                     species  length  weight  w_l_ratio
# 4075  Sillaginopsis panijus   30.56    6.12       0.20
# 4076  Sillaginopsis panijus   29.66    6.11       0.21
# 4077  Sillaginopsis panijus   32.81    6.25       0.19
# 4078  Sillaginopsis panijus   29.78    6.11       0.21
# 4079  Sillaginopsis panijus   31.62    6.14       0.19

# %% [markdown]
# # Describe dataset

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4080 entries, 0 to 4079
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   species    4080 non-null   object
#  1   length     4080 non-null   float64
#  2   weight     4080 non-null   float64
#  3   w_l_ratio  4080 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 127.6+ KB

# %%
df_data.describe()
# Out:
#             length       weight    w_l_ratio
# count  4080.000000  4080.000000  4080.000000
# mean     17.353544     3.739875     0.252782
# std       7.114684     1.040365     0.123046
# min       6.360000     2.050000     0.080000
# 25%      11.327500     3.070000     0.170000
# 50%      17.350000     3.310000     0.190000
# 75%      22.585000     4.100000     0.340000
# max      33.860000     6.290000     0.640000

# %%
df_data.isnull().sum().sort_values(ascending=False).rename("Missing values")
# Out:
# species      0
# length       0
# weight       0
# w_l_ratio    0
# Name: Missing values, dtype: int64

# %%
# Check duplicated rows
print("Duplicated rows: ", df_data.duplicated().sum())
# Out:
# Duplicated rows:  109

# %%
df_data.shape
# Out:
# (4080, 4)

# %%
# Drop dulicated rows
df_data.drop_duplicates(inplace=True)
df_data.shape
# Out:
# (3971, 4)

# %%
# Check duplicated rows
print("Duplicated rows: ", df_data.duplicated().sum())
# Out:
# Duplicated rows:  0

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_data.drop('species',axis=1), df_data['species'], test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2660, 3), (1311, 3), (2660,), (1311,))

# %% [markdown]
# # Fit model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver="liblinear", max_iter=1000)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
y_pred = model.predict(X_test)

y_pred
# Out:
# array(['Pethia conchonius', 'Otolithoides pama', 'Puntius lateristriga',
#        ..., 'Setipinna taty', 'Otolithoides pama', 'Anabas testudineus'],
#       dtype=object)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

print(classification_report(y_test, y_pred))
# Out:
#                         precision    recall  f1-score   support
#
#     Anabas testudineus       0.99      0.95      0.97       174
#      Coilia dussumieri       0.98      1.00      0.99       136
# Otolithoides biauritus       0.92      0.07      0.14       150
#      Otolithoides pama       0.99      0.98      0.99       139
#      Pethia conchonius       0.96      0.99      0.97       146
#   Polynemus paradiseus       0.93      0.95      0.94       149
#   Puntius lateristriga       0.99      1.00      1.00       116
#         Setipinna taty       0.53      0.99      0.69       153
#  Sillaginopsis panijus       1.00      1.00      1.00       148
#
#               accuracy                           0.88      1311
#              macro avg       0.92      0.88      0.85      1311
#           weighted avg       0.92      0.88      0.85      1311

# %%
print(f"Accuracy: {(accuracy_score(y_test, y_pred)*100):.2f} %")
# Out:
# Accuracy: 87.80 %
